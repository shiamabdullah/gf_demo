# %%
#!/usr/bin/env python
# coding: utf-8

import pandas as pd
import numpy as np
from sklearn.preprocessing import OrdinalEncoder
from pickle import dump
from pickle import load
# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import  Model
from tensorflow.keras.layers import BatchNormalization

import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1704\2471723232.py in <module>
#      10 np.set_printoptions(precision=3, suppress=True)
#      11
# ---> 12 import tensorflow as tf
#      13 from tensorflow.keras import layers
#      14 from tensorflow.keras.layers import Input, Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
validate_csv_path=r'.\validate_data_MemCompData_22FDX_12LPP_1.csv'
mem_validate=pd.read_csv(validate_csv_path)
#column_words = "Words"
#del mem_validate.Words

# %%
mem_validate
del mem_validate['Words']

# %%
mem_validate
# Out:
#     Comp   Tech           Type Mem_Type Port_Type  Capacity_kb  Bits  VDDPE  \
# 0    ARM  12LPP  rf_sp_rvt_mvt       RF    Single         18.0    36   0.88
# 1    ARM  12LPP  rf_sp_rvt_mvt       RF    Single         18.0    36   0.72
# 2    ARM  12LPP  rf_sp_rvt_mvt       RF    Single         18.0    36   0.80
# 3    ARM  12LPP  rf_2p_rvt_mvt       RF       Two          2.0    32   0.88
# 4    ARM  12LPP  rf_2p_rvt_mvt       RF       Two          2.0    32   0.72
# ..   ...    ...            ...      ...       ...          ...   ...    ...
# 91  SNPS  22FDX           SDPV     SRAM       Two         72.0    72   0.88
# 92  SNPS  22FDX           SDPV     SRAM       Two         72.0    72   0.72
# 93  SNPS  22FDX           SDPV     SRAM       Two        144.0    72   0.80
# 94  SNPS  22FDX           SDPV     SRAM       Two        144.0    72   0.88
# 95  SNPS  22FDX           SDPV     SRAM       Two        144.0    72   0.72
#
#     VDDCE          Corner
# 0    0.88  ffg_0.88v_125c
# ...

# %%
my_oe = load(open('encoder.pkl', 'rb'))
my_oe
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator OrdinalEncoder from version 1.1.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# OrdinalEncoder()

# %%
#category_columns_list = ['Comp', 'Tech', 'Type', 'Mem_Type', 'Port_Type', 'Capacity_kb', 'Bits', 'VDDPE', 'VDDCE', 'Corner']
category_columns_list = ['Comp', 'Tech', 'Type', 'Mem_Type', 'Port_Type', 'Corner']

# %%
mem_validate[category_columns_list]=my_oe.fit_transform(mem_validate[category_columns_list])

# %%
mem_validate
# Out:
#     Comp  Tech  Type  Mem_Type  Port_Type  Capacity_kb  Bits  VDDPE  VDDCE  \
# 0    0.0   0.0   5.0       0.0        0.0         18.0    36   0.88   0.88
# 1    0.0   0.0   5.0       0.0        0.0         18.0    36   0.72   0.72
# 2    0.0   0.0   5.0       0.0        0.0         18.0    36   0.80   0.80
# 3    0.0   0.0   4.0       0.0        1.0          2.0    32   0.88   0.88
# 4    0.0   0.0   4.0       0.0        1.0          2.0    32   0.72   0.72
# ..   ...   ...   ...       ...        ...          ...   ...    ...    ...
# 91   1.0   1.0   3.0       1.0        1.0         72.0    72   0.88   0.88
# 92   1.0   1.0   3.0       1.0        1.0         72.0    72   0.72   0.72
# 93   1.0   1.0   3.0       1.0        1.0        144.0    72   0.80   0.80
# 94   1.0   1.0   3.0       1.0        1.0        144.0    72   0.88   0.88
# 95   1.0   1.0   3.0       1.0        1.0        144.0    72   0.72   0.72
#
#     Corner
# 0      0.0
# 1      1.0
# 2      2.0
# 3      0.0
# ...

# %%
model_name = "mem_model"
x1 = keras.models.load_model('./gen_model/'+model_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1704\278039335.py in <module>
#       1 model_name = "mem_model"
# ----> 2 x1 = tf.keras.models.load_model('./gen_model/'+model_name)
#
# NameError: name 'tf' is not defined

# %%
x1_pred=x1.predict(mem_validate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1704\3819160822.py in <module>
# ----> 1 x1_pred=x1.predict(mem_validate)
#
# NameError: name 'x1' is not defined

# %%
x1_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1704\1235702040.py in <module>
# ----> 1 x1_pred
#
# NameError: name 'x1_pred' is not defined
